# %% [markdown]
# # Hough LInes

# %% [markdown]
# ### Import resources and display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
os.chdir(r'C:\Users\atavares\/'
         r'PycharmProjects\ComputerVision')

import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
image = cv2.imread('data/images/phone.jpg')

# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %% [markdown]
# ### Perform edge detection

# %%
# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Define our parameters for Canny
low_threshold = 50
high_threshold = 100
edges = cv2.Canny(gray, low_threshold, high_threshold)

plt.imshow(edges, cmap='gray')

# %% [markdown]
# ### Find lines using a Hough transform

# %%
# Define the Hough transform parameters
# Make a blank the same size as our image to draw on
rho = 1 # Resolution of the detection in pixels
theta = np.pi/180 # Resolution of the detection in degrees
# Minimum number of Hough space intersections it takes to find a line
threshold = 60
min_line_length = 100 # Minimum line length
max_line_gap = 5 # Minimum Gap between discontinuous line segments

#  Create an image copy to draw lines on
line_image = np.copy(image)

# Run Hough on the edge-detected image
lines = cv2.HoughLinesP(edges, rho, theta, threshold,
                        np.array([]), min_line_length,
                        max_line_gap)

# Iterate over the output 'lines' and draw lines on the
# image copy
for line in lines:
    for x1, y1, x2, y2 in line:
        cv2.line(line_image, (x1, y1), (x2, y2),
                 (255, 0, 0), 5)
plt.imshow(line_image)
